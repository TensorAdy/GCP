# %%
# %%html
# This cell will print out a <b> HTML </b> string.
# Out:
# This cell will print out a <b> HTML </b> string.

# %%
a = 3
b = a + 5
print("a={} b={}".format(a,b))
# Out:
# a=3 b=8

# %%
# !pwd
# Out:
# /home/jupyter

# %%
# !pwd
# Out:
# /home/jupyter

# %%
# !pip freeze
# Out:
# absl-py==0.8.1
# adal @ file:///home/conda/feedstock_root/build_artifacts/adal_1591523462562/work
# alabaster==0.7.12
# anaconda-client==1.7.2
# anaconda-project==0.8.3
# ansiwrap==0.8.4
# apache-beam==2.22.0
# appdirs==1.4.3
# argh==0.26.2
# arrow @ file:///home/conda/feedstock_root/build_artifacts/arrow_1592592061553/work
# asn1crypto @ file:///home/conda/feedstock_root/build_artifacts/asn1crypto_1588618038116/work
# astroid @ file:///home/conda/feedstock_root/build_artifacts/astroid_1591645081755/work
# astropy==4.0.1.post1
# astunparse==1.6.3
# async-generator==1.10
# atomicwrites @ file:///home/conda/feedstock_root/build_artifacts/atomicwrites_1588182545583/work
# attrs==19.3.0
# autopep8==1.5.2
# avro-python3==1.9.2.1
# Babel==2.8.0
# backcall @ file:///home/conda/feedstock_root/build_artifacts/backcall_1592338393461/work
# backports.shutil-get-terminal-size==1.0.0
# bcolz==1.2.1
# beautifulsoup4 @ file:///home/conda/feedstock_root/build_artifacts/beautifulsoup4_1589761456552/work
# binaryornot==0.4.4
# bitarray @ file:///home/conda/feedstock_root/build_artifacts/bitarray_1589849257874/work
# bkcharts==0.2
# black==19.10b0
# bleach @ file:///home/conda/feedstock_root/build_artifacts/bleach_1588608214987/work
# blinker==1.4
# bokeh @ file:///home/conda/feedstock_root/build_artifacts/bokeh_1592869573618/work
# boto==2.49.0
# Bottleneck==1.3.2
# brotlipy==0.7.0
# cachetools @ file:///home/conda/feedstock_root/build_artifacts/cachetools_1593420445823/work
# certifi==2020.6.20
# cffi==1.14.0
# chardet==3.0.4
# click==7.1.2
# cloudpickle @ file:///home/conda/feedstock_root/build_artifacts/cloudpickle_1588164361239/work
# clyent==1.2.2
# colorama==0.4.3
# conda==4.8.3
# conda-package-handling==1.7.0
# confuse @ file:///home/conda/feedstock_root/build_artifacts/confuse_1593279073800/work
# contextlib2==0.6.0.post1
# cookiecutter==1.7.2
# crcmod==1.7
# cryptography==2.9.2
# cycler==0.10.0
# Cython @ file:///home/conda/feedstock_root/build_artifacts/cython_1591799499719/work
# cytoolz==0.10.1
# dask @ file:///home/conda/feedstock_root/build_artifacts/dask-core_1592593303100/work
# decorator==4.4.2
# defusedxml==0.6.0
# diff-match-patch==20181111
# dill==0.3.1.1
# distributed @ file:///home/conda/feedstock_root/build_artifacts/distributed_1592593830507/work
# docker @ file:///home/conda/feedstock_root/build_artifacts/docker-py_1591119474931/work
# docker-pycreds==0.4.0
# docopt==0.6.2
# docutils==0.16
# entrypoints==0.3
# et-xmlfile==1.0.1
# fastavro==0.23.5
# fastcache==1.1.0
# fasteners==0.15
# filelock @ file:///home/conda/feedstock_root/build_artifacts/filelock_1589994591731/work
# flake8==3.7.9
# Flask==1.1.2
# fsspec @ file:///home/conda/feedstock_root/build_artifacts/fsspec_1589989738418/work
# future==0.18.2
# gast==0.3.3
# gcsfs @ file:///home/conda/feedstock_root/build_artifacts/gcsfs_1588858323173/work
# gevent @ file:///home/conda/feedstock_root/build_artifacts/gevent_1592657467591/work
# gitdb @ file:///home/conda/feedstock_root/build_artifacts/gitdb_1588651542737/work
# GitPython @ file:///home/conda/feedstock_root/build_artifacts/gitpython_1590897464411/work
# glob2==0.7
# gmpy2==2.1.0b1
# google-api-core==1.21.0
# google-api-python-client @ file:///home/conda/feedstock_root/build_artifacts/google-api-python-client_1591125360815/work
# google-apitools==0.5.31
# google-auth==1.18.0
# google-auth-httplib2==0.0.3
# google-auth-oauthlib==0.4.1
# google-cloud-bigquery==1.25.0
# google-cloud-bigtable==1.2.1
# google-cloud-core==1.3.0
# google-cloud-dataproc==1.0.0
# google-cloud-datastore==1.12.0
# google-cloud-dlp==0.13.0
# google-cloud-firestore==1.7.0
# google-cloud-kms==1.4.0
# google-cloud-language==1.3.0
# google-cloud-logging==1.15.0
# google-cloud-pubsub==1.6.0
# google-cloud-scheduler==1.3.0
# google-cloud-spanner==1.17.1
# google-cloud-speech==1.3.2
# google-cloud-storage==1.29.0
# google-cloud-tasks==1.5.0
# google-cloud-translate==2.0.1
# google-cloud-videointelligence==1.15.0
# google-cloud-vision==1.0.0
# google-pasta==0.2.0
# google-resumable-media==0.5.1
# googleapis-common-protos==1.51.0
# greenlet @ file:///home/conda/feedstock_root/build_artifacts/greenlet_1591368821264/work
# grpc-google-iam-v1==0.12.3
# grpcio==1.30.0
# grpcio-gcp==0.2.2
# h5py @ file:///home/conda/feedstock_root/build_artifacts/h5py_1593217410729/work
# hdfs==2.5.8
# HeapDict==1.0.1
# html5lib @ file:///home/conda/feedstock_root/build_artifacts/html5lib_1592930327044/work
# htmlmin==0.1.12
# httplib2 @ file:///home/conda/feedstock_root/build_artifacts/httplib2_1590007784658/work
# hypothesis @ file:///home/conda/feedstock_root/build_artifacts/hypothesis_1593228013254/work
# idna @ file:///home/conda/feedstock_root/build_artifacts/idna_1593328102638/work
# imagecodecs @ file:///home/conda/feedstock_root/build_artifacts/imagecodecs_1593295475914/work
# ImageHash @ file:///home/conda/feedstock_root/build_artifacts/imagehash_1588182723834/work
# imageio==2.8.0
# imagesize==1.2.0
# importlib-metadata @ file:///home/conda/feedstock_root/build_artifacts/importlib-metadata_1593211369179/work
# intervaltree==3.0.2
# ipykernel @ file:///home/conda/feedstock_root/build_artifacts/ipykernel_1590020200501/work/dist/ipykernel-5.3.0-py3-none-any.whl
# ipython @ file:///home/conda/feedstock_root/build_artifacts/ipython_1593235460530/work
# ipython-genutils==0.2.0
# ipython-sql @ file:///home/conda/feedstock_root/build_artifacts/ipython-sql_1588134460796/work
# ipywidgets==7.5.1
# isort==4.3.21
# itsdangerous==1.1.0
# jdcal==1.4.1
# jedi==0.15.2
# jeepney==0.4.3
# Jinja2==2.11.2
# jinja2-time==0.2.0
# joblib @ file:///home/conda/feedstock_root/build_artifacts/joblib_1589812474002/work
# json5 @ file:///home/conda/feedstock_root/build_artifacts/json5_1591810480056/work
# jsonschema==3.2.0
# jupyter==1.0.0
# jupyter-aihub-deploy-extension @ file:///opt/conda/conda-bld/dlenv-base_1593468110918/work/packages/aihub/jupyter_aihub_deploy_extension
# jupyter-client==6.1.3
# jupyter-console==6.1.0
# jupyter-core==4.6.3
# jupyter-http-over-ws==0.0.8
# jupyterlab==1.2.16
# jupyterlab-git @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab-git_1591177886792/work
# jupyterlab-server @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab_server_1590229434073/work
# Keras==2.3.1
# Keras-Applications==1.0.8
# Keras-Preprocessing==1.1.2
# keras-tuner==1.0.1
# keyring @ file:///home/conda/feedstock_root/build_artifacts/keyring_1588433935863/work
# kiwisolver==1.2.0
# kubernetes @ file:///home/conda/feedstock_root/build_artifacts/python-kubernetes_1588618980778/work
# lazy-object-proxy==1.4.3
# libarchive-c==2.9
# lief==0.9.0
# llvmlite==0.32.1
# locket==0.2.0
# lxml @ file:///home/conda/feedstock_root/build_artifacts/lxml_1589927514031/work
# Markdown @ file:///home/conda/feedstock_root/build_artifacts/markdown_1589366472132/work
# MarkupSafe==1.1.1
# matplotlib @ file:///home/conda/feedstock_root/build_artifacts/matplotlib-base_1592576108701/work
# mccabe==0.6.1
# missingno==0.4.2
# mistune==0.8.4
# mkl-fft==1.1.0
# mkl-random==1.1.0
# mkl-service==2.3.0
# ml-metadata==0.22.1
# mock @ file:///home/conda/feedstock_root/build_artifacts/mock_1588618847833/work
# monotonic==1.5
# more-itertools @ file:///home/conda/feedstock_root/build_artifacts/more-itertools_1592197792446/work
# mpmath==1.1.0
# msgpack==1.0.0
# multipledispatch==0.6.0
# mypy-extensions==0.4.3
# nb-conda==2.2.1
# nb-conda-kernels==2.2.3
# nbclient @ file:///home/conda/feedstock_root/build_artifacts/nbclient_1591814389930/work
# nbconvert==5.6.1
# nbdime @ file:///home/conda/feedstock_root/build_artifacts/nbdime_1588773248389/work
# nbformat==5.0.6
# nbpresent==3.0.2
# nest-asyncio @ file:///home/conda/feedstock_root/build_artifacts/nest-asyncio_1588514211290/work
# networkx==2.4
# nltk==3.4.4
# nose==1.3.7
# notebook @ file:///home/conda/feedstock_root/build_artifacts/notebook_1588887226267/work
# notebook-executor @ file:///opt/conda/conda-bld/dlenv-base_1593468110918/work/packages/notebook_executor
# numba @ file:///home/conda/feedstock_root/build_artifacts/numba_1590133695837/work
# numexpr==2.7.1
# numpy==1.19.0
# numpydoc @ file:///home/conda/feedstock_root/build_artifacts/numpydoc_1590519183599/work
# oauth2client==3.0.0
# oauthlib==3.1.0
# olefile==0.46
# openpyxl==3.0.3
# opt-einsum==3.2.1
# packaging @ file:///home/conda/feedstock_root/build_artifacts/packaging_1589925210001/work
# pandas @ file:///home/conda/feedstock_root/build_artifacts/pandas_1592421991297/work
# pandas-profiling @ file:///home/conda/feedstock_root/build_artifacts/pandas-profiling_1589366436905/work
# pandocfilters==1.4.2
# papermill==2.1.0
# parso==0.5.2
# partd==1.1.0
# path @ file:///home/conda/feedstock_root/build_artifacts/path_1590330789695/work
# path.py==12.0.2
# pathlib2==2.3.5
# pathspec==0.8.0
# pathtools==0.1.2
# patsy==0.5.1
# pbr==5.4.5
# pep8==1.7.1
# pexpect==4.8.0
# phik @ file:///home/conda/feedstock_root/build_artifacts/phik_1590331950347/work
# pickleshare==0.7.5
# Pillow==7.1.2
# pkginfo==1.5.0.1
# pluggy @ file:///home/conda/feedstock_root/build_artifacts/pluggy_1592827471208/work
# ply==3.11
# poyo==0.5.0
# prettytable==0.7.2
# prometheus-client @ file:///home/conda/feedstock_root/build_artifacts/prometheus_client_1590412252446/work
# promise==2.3
# prompt-toolkit @ file:///home/conda/feedstock_root/build_artifacts/prompt-toolkit_1592500439797/work
# protobuf==3.12.3
# psutil==5.7.0
# ptyprocess==0.6.0
# py @ file:///home/conda/feedstock_root/build_artifacts/py_1593088446458/work
# pyarrow==0.17.1
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycodestyle==2.5.0
# pycosat==0.6.3
# pycparser @ file:///home/conda/feedstock_root/build_artifacts/pycparser_1593275161868/work
# pycrypto==2.6.1
# pycurl==7.43.0.5
# pydocstyle==5.0.2
# pydot==1.4.1
# pyflakes==2.1.1
# Pygments==2.6.1
# PyJWT==1.7.1
# pylint @ file:///home/conda/feedstock_root/build_artifacts/pylint_1592404303629/work
# pymongo==3.10.1
# pyodbc==4.0.30
# pyOpenSSL==19.1.0
# pyparsing==2.4.7
# PyQt5==5.12.3
# PyQt5-sip==4.19.18
# PyQtChart==5.12
# PyQtWebEngine==5.12.1
# pyrsistent==0.16.0
# PySocks==1.7.1
# pytest==5.4.3
# pytest-arraydiff==0.3
# pytest-astropy==0.7.0
# pytest-astropy-header==0.1.2
# pytest-doctestplus @ file:///home/conda/feedstock_root/build_artifacts/pytest-doctestplus_1591908454504/work
# pytest-openfiles @ file:///home/conda/feedstock_root/build_artifacts/pytest-openfiles_1591909410901/work
# pytest-remotedata==0.3.1
# python-dateutil==2.8.1
# python-jsonrpc-server @ file:///home/conda/feedstock_root/build_artifacts/python-jsonrpc-server_1588783985962/work
# python-language-server==0.31.10
# python-slugify==4.0.0
# pytz==2020.1
# PyWavelets==1.1.1
# pyxdg==0.26
# PyYAML==5.3.1
# pyzmq==19.0.1
# QDarkStyle==2.8.1
# QtAwesome @ file:///home/conda/feedstock_root/build_artifacts/qtawesome_1588715536397/work
# qtconsole @ file:///home/conda/feedstock_root/build_artifacts/qtconsole_1592845750760/work
# QtPy==1.9.0
# regex @ file:///home/conda/feedstock_root/build_artifacts/regex_1591646121522/work
# requests @ file:///home/conda/feedstock_root/build_artifacts/requests_1592425495151/work
# requests-oauthlib==1.3.0
# retrying==1.3.3
# rope @ file:///home/conda/feedstock_root/build_artifacts/rope_1588950285934/work
# rsa @ file:///home/conda/feedstock_root/build_artifacts/rsa_1591996208734/work
# Rtree==0.9.4
# ruamel-yaml==0.15.80
# scikit-image==0.17.2
# scikit-learn @ file:///home/conda/feedstock_root/build_artifacts/scikit-learn_1589920855303/work
# scipy @ file:///home/conda/feedstock_root/build_artifacts/scipy_1593253469108/work
# seaborn @ file:///home/conda/feedstock_root/build_artifacts/seaborn-base_1591878760859/work
# SecretStorage==3.1.2
# Send2Trash==1.5.0
# simplegeneric==0.8.1
# simplejson @ file:///home/conda/feedstock_root/build_artifacts/simplejson_1588608463837/work
# singledispatch==3.4.0.3
# sip==4.19.23
# six @ file:///home/conda/feedstock_root/build_artifacts/six_1590081179328/work
# smmap @ file:///home/conda/feedstock_root/build_artifacts/smmap_1588651577140/work
# snowballstemmer==2.0.0
# sortedcollections @ file:///home/conda/feedstock_root/build_artifacts/sortedcollections_1591583091437/work
# sortedcontainers @ file:///home/conda/feedstock_root/build_artifacts/sortedcontainers_1591999956871/work
# soupsieve @ file:///home/conda/feedstock_root/build_artifacts/soupsieve_1589778966114/work
# Sphinx @ file:///home/conda/feedstock_root/build_artifacts/sphinx_1592165595094/work
# sphinxcontrib-applehelp==1.0.2
# sphinxcontrib-devhelp==1.0.2
# sphinxcontrib-htmlhelp==1.0.3
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.3
# sphinxcontrib-serializinghtml==1.1.4
# sphinxcontrib-websupport @ file:///home/conda/feedstock_root/build_artifacts/sphinxcontrib-websupport_1593344032344/work
# spyder @ file:///home/conda/feedstock_root/build_artifacts/spyder_1588993801519/work
# spyder-kernels @ file:///home/conda/feedstock_root/build_artifacts/spyder-kernels_1588785827687/work
# SQLAlchemy @ file:///home/conda/feedstock_root/build_artifacts/sqlalchemy_1593116989295/work
# sqlparse==0.3.1
# statsmodels @ file:///home/conda/feedstock_root/build_artifacts/statsmodels_1591963256838/work
# sympy @ file:///home/conda/feedstock_root/build_artifacts/sympy_1590335528566/work
# tables==3.6.1
# tabulate==0.8.7
# tangled-up-in-unicode @ file:///home/conda/feedstock_root/build_artifacts/tangled-up-in-unicode_1589363771888/work
# tblib==1.6.0
# tenacity @ file:///home/conda/feedstock_root/build_artifacts/tenacity_1588242769366/work
# tensorboard==2.2.2
# tensorboard-plugin-wit==1.7.0
# tensorflow @ file:///opt/conda/conda-bld/dlenv-tf-2-2-cpu_1593508078155/work/tensorflow-2.2.0-cp37-cp37m-linux_x86_64.whl
# tensorflow-data-validation==0.22.2
# tensorflow-datasets==3.1.0
# tensorflow-enterprise-addons @ file:///opt/conda/conda-bld/dlenv-tf-2-2-cpu_1593508078155/work/tensorflow_enterprise_addons-0.0.0-py3-none-any.whl
# tensorflow-estimator==2.2.0
# tensorflow-hub==0.8.0
# tensorflow-io==0.13.0
# tensorflow-metadata==0.22.2
# tensorflow-model-analysis==0.22.2
# tensorflow-probability==0.9.0
# tensorflow-serving-api==2.1.0
# tensorflow-transform==0.22.0
# termcolor==1.1.0
# terminado==0.8.3
# terminaltables==3.1.0
# testpath==0.4.4
# text-unidecode==1.3
# textwrap3==0.9.2
# tfx==0.22.0
# tfx-bsl==0.22.1
# threadpoolctl @ file:///tmp/tmp79xdzxkt/threadpoolctl-2.1.0-py3-none-any.whl
# tifffile @ file:///home/conda/feedstock_root/build_artifacts/tifffile_1593508478078/work
# toml @ file:///home/conda/feedstock_root/build_artifacts/toml_1589469402899/work
# toolz==0.10.0
# tornado==6.0.4
# tqdm @ file:///home/conda/feedstock_root/build_artifacts/tqdm_1593390011681/work
# traitlets==4.3.3
# typed-ast==1.4.1
# typing-extensions @ file:///home/conda/feedstock_root/build_artifacts/typing_extensions_1588470653596/work
# ujson==1.35
# unicodecsv==0.14.1
# Unidecode==1.1.1
# uritemplate==3.0.1
# urllib3==1.25.9
# visions @ file:///home/conda/feedstock_root/build_artifacts/visions_1589284473785/work
# watchdog @ file:///home/conda/feedstock_root/build_artifacts/watchdog_1593120501703/work
# wcwidth @ file:///home/conda/feedstock_root/build_artifacts/wcwidth_1592931742287/work
# webencodings==0.5.1
# websocket-client==0.57.0
# Werkzeug==1.0.1
# whichcraft==0.6.1
# widgetsnbextension==3.5.1
# witwidget==1.7.0
# wrapt==1.12.1
# wurlitzer==2.0.0
# xlrd==1.2.0
# XlsxWriter @ file:///home/conda/feedstock_root/build_artifacts/xlsxwriter_1590799523302/work
# xlwt==1.3.0
# yapf==0.29.0
# zict==2.0.0
# zipp==3.1.0
# zope.event @ file:///home/conda/feedstock_root/build_artifacts/zope.event_1591372894284/work
# zope.interface==5.1.0

# %%
# !pip install --upgrade google-cloud-bigquery
# Out:
# Collecting google-cloud-bigquery
#   Downloading google_cloud_bigquery-1.26.1-py2.py3-none-any.whl (170 kB)
#      |████████████████████████████████| 170 kB 4.2 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: google-resumable-media<2.0dev,>=0.5.0 in /opt/conda/lib/python3.7/site-packages (from google-cloud-bigquery) (0.5.1)
# Requirement already satisfied, skipping upgrade: google-api-core<2.0dev,>=1.21.0 in /opt/conda/lib/python3.7/site-packages (from google-cloud-bigquery) (1.21.0)
# Requirement already satisfied, skipping upgrade: six<2.0.0dev,>=1.13.0 in /opt/conda/lib/python3.7/site-packages (from google-cloud-bigquery) (1.15.0)
# Requirement already satisfied, skipping upgrade: google-cloud-core<2.0dev,>=1.1.0 in /opt/conda/lib/python3.7/site-packages (from google-cloud-bigquery) (1.3.0)
# Requirement already satisfied, skipping upgrade: google-auth<2.0dev,>=1.18.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery) (1.18.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.12.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery) (3.12.3)
# Requirement already satisfied, skipping upgrade: googleapis-common-protos<2.0dev,>=1.6.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery) (1.51.0)
# Requirement already satisfied, skipping upgrade: pytz in /opt/conda/lib/python3.7/site-packages (from google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery) (2020.1)
# Requirement already satisfied, skipping upgrade: setuptools>=34.0.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery) (47.3.1.post20200616)
# Requirement already satisfied, skipping upgrade: requests<3.0.0dev,>=2.18.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery) (2.24.0)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from google-auth<2.0dev,>=1.18.0->google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery) (4.1.1)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.7/site-packages (from google-auth<2.0dev,>=1.18.0->google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery) (0.2.8)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3" in /opt/conda/lib/python3.7/site-packages (from google-auth<2.0dev,>=1.18.0->google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery) (4.6)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery) (1.25.9)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery) (2020.6.20)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery) (2.10)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.18.0->google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery) (0.4.8)
# Installing collected packages: google-cloud-bigquery
#   Attempting uninstall: google-cloud-bigquery
#     Found existing installation: google-cloud-bigquery 1.25.0
#     Uninstalling google-cloud-bigquery-1.25.0:
#       Successfully uninstalled google-cloud-bigquery-1.25.0
# Successfully installed google-cloud-bigquery-1.26.1

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# %%bigquery
# SELECT
#   COUNTIF(arr_delay >= 15)/COUNT(arr_delay) AS frac_delayed
# FROM flights.tzcorr
# Out:
#    frac_delayed
# 0      0.186111

# %%
# %%bigquery df
# SELECT ARR_DELAY, DEP_DELAY
# FROM flights.tzcorr
# WHERE DEP_DELAY >= 10 AND RAND() < 0.01

# %%
df.describe()
# Out:
#           ARR_DELAY     DEP_DELAY
# count  12785.000000  12878.000000
# mean      45.337036     50.413108
# std       61.153492     59.806185
# min      -42.000000     10.000000
# 25%       11.000000     17.000000
# 50%       27.000000     30.000000
# 75%       59.000000     60.000000
# max     1033.000000   1102.000000

# %%
sns.set_style("whitegrid")
sns.set(font="DejaVu Sans")
ax = sns.violinplot(data=df, x='ARR_DELAY', inner='box', orient='h')
